# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\priya\Downloads\Flats Uncleaned Dataset.csv")
print(df.head())
# Out:
#                                        property_name areaWithType square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
#
#        transaction            status        floor      furnishing  \
# 0     New Property  Poss. by Oct '24  5 out of 10     Unfurnished
# 1     New Property  Poss. by Jan '26  6 out of 14     Unfurnished
# 2           Resale     Ready to Move  5 out of 13  Semi-Furnished
# 3     New Property     Ready to Move  6 out of 14     Unfurnished
# 4  Orchid Fantasia      New Property  Unfurnished               2
#
#         facing                                        description  \
# ...

# %%
df["transaction"].fillna(df["transaction"].mode()[0],inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_26392\3952696279.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["transaction"].fillna(df["transaction"].mode()[0],inplace=True)
# 0          New Property
# 1          New Property
# 2                Resale
# 3          New Property
# 4       Orchid Fantasia
# ...

# %%
df["transaction"].isnull().sum()
# Out:
# np.int64(104)

# %%
df["price_per_sqft"].fillna(df["price_per_sqft"].mode(),inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_26392\1284837679.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["price_per_sqft"].fillna(df["price_per_sqft"].mode(),inplace=True)
# 0       ₹2,891 per sqft
# 1       ₹3,551 per sqft
# 2       ₹3,800 per sqft
# 3       ₹3,966 per sqft
# 4       ₹3,600 per sqft
# ...

# %%
df.isnull().sum()
# Out:
# property_name        0
# areaWithType         0
# square_feet          0
# transaction        104
# status               1
# floor               45
# furnishing         340
# facing             589
# description       1371
# price_per_sqft     368
# price                0
# dtype: int64

# %%
df["description"].fillna(df["description"].mode()[0],inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_26392\1085692302.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["description"].fillna(df["description"].mode()[0],inplace=True)
# 0       Luxury project with basement parking, Solar ro...
# 1       2 And 3 BHK Luxurious Flat for Sell In New Alt...
# ...

# %%
df.isnull().sum()
# Out:
# property_name        0
# areaWithType         0
# square_feet          0
# transaction        104
# status               1
# floor               45
# furnishing         340
# facing             589
# description       1371
# price_per_sqft     368
# price                0
# dtype: int64

# %%
df["status"].fillna(df["status"].mode()[0],inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_26392\3297417644.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["status"].fillna(df["status"].mode()[0],inplace=True)
# 0       Poss. by Oct '24
# 1       Poss. by Jan '26
# 2          Ready to Move
# 3          Ready to Move
# 4           New Property
# ...

# %%
df.isnull().sum()
# Out:
# property_name        0
# areaWithType         0
# square_feet          0
# transaction        104
# status               1
# floor               45
# furnishing         340
# facing             589
# description       1371
# price_per_sqft     368
# price                0
# dtype: int64

# %%
df["furnishing"].fillna(df["furnishing"].mode()[0],inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_26392\1409659827.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["furnishing"].fillna(df["furnishing"].mode()[0],inplace=True)
# 0          Unfurnished
# 1          Unfurnished
# 2       Semi-Furnished
# 3          Unfurnished
# 4                    2
#              ...
# ...

# %%
df.isnull().sum(0)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_26392\1381888268.py:1: Pandas4Warning: Starting with pandas version 4.0 all arguments of sum will be keyword-only.
#   df.isnull().sum(0)
# property_name        0
# areaWithType         0
# square_feet          0
# transaction        104
# status               1
# floor               45
# furnishing         340
# facing             589
# description       1371
# price_per_sqft     368
# price                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(109)

# %%
df.drop_duplicates(inplace=True)

# %%
df["floor"].fillna(df["floor"].mode()[0],inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_26392\1949483732.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["floor"].fillna(df["floor"].mode()[0],inplace=True)
# 0       5 out of 10
# 1       6 out of 14
# 2       5 out of 13
# 3       6 out of 14
# 4       Unfurnished
#            ...
# 4520    5 out of 12
# ...

# %%
df.isnull().sum()
# Out:
# property_name        0
# areaWithType         0
# square_feet          0
# transaction        103
# status               1
# floor               45
# furnishing         331
# facing             563
# description       1331
# price_per_sqft     358
# price                0
# dtype: int64

# %%
df["transaction"].unique()
# Out:
# <StringArray>
# [                'New Property',                       'Resale',
#               'Orchid Fantasia',                  'Unfurnished',
#               'Orchid Gardenia',                        'Congo',
#                     'Furnished',                            nan,
#                'Semi-Furnished',       'Main Road, Garden/Park',
#                             '1',                            '3',
#                             '4',                          'Yes',
#                            'No',                'Mahavir Nagar',
#                     '3 Covered',             'Shagun Residency',
#                             '2',                    'Main Road',
#                          '10 m',                        'Other',
#                     '1 Covered',               'Soham Elegance',
#                   'Garden/Park',            'Aakash Echo Point',
#            'Sundaram Residency',                            '5',
# ...

# %%
df.isnull().sum()
# Out:
# property_name        0
# areaWithType         0
# square_feet          0
# transaction        103
# status               1
# floor               45
# furnishing         331
# facing             563
# description       1331
# price_per_sqft     358
# price                0
# dtype: int64
