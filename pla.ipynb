# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\priya\Downloads\students_data_uncleaned.csv")
print(df.head())
# Out:
#    Student_ID       Name   Age  Gender Department        City  Marks  \
# 0        1001  Student_1  19.0    Male        ECE  Chandigarh   63.0
# 1        1002  Student_2  19.0    Male         CE    Amritsar    NaN
# 2        1003  Student_3  19.0    Male         IT      Jaipur   38.0
# 3        1004  Student_4  21.0  Female         IT    Amritsar    NaN
# 4        1005  Student_5  20.0  Female        ECE         NaN   54.0
#
#    Attendance
# 0        68.0
# 1        61.0
# 2        95.0
# 3        60.0
# 4        73.0

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_7224\1698716155.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# 0       19.0
# 1       19.0
# 2       19.0
# 3       21.0
# 4       20.0
#         ...
# 2001    23.0
# 2002    21.0
# 2003    25.0
# 2004    25.0
# 2005    25.0
# Name: Age, Length: 2006, dtype: float64

# %%
df['Age'].mean()
# Out:
# np.float64(21.530715005035248)

# %%
df.isnull().sum()
# Out:
# Student_ID     0
# Name           0
# Age           20
# Gender         9
# Department     9
# City           8
# Marks          7
# Attendance     6
# dtype: int64

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_7224\3657246551.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# 0         Male
# 1         Male
# 2         Male
# 3       Female
# 4       Female
#          ...
# 2001    Female
# 2002    Female
# 2003      Male
# 2004      Male
# 2005      Male
# Name: Gender, Length: 2006, dtype: str

# %%
df['Gender'].mode()[0]
# Out:
# 'Female'

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_7224\3657246551.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# 0         Male
# 1         Male
# 2         Male
# 3       Female
# 4       Female
#          ...
# 2001    Female
# 2002    Female
# 2003      Male
# 2004      Male
# 2005      Male
# Name: Gender, Length: 2006, dtype: str

# %%
df.isnull().sum()
# Out:
# Student_ID     0
# Name           0
# Age           20
# Gender         9
# Department     9
# City           8
# Marks          7
# Attendance     6
# dtype: int64

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=False)
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3       Female
# 4       Female
#          ...
# 2001    Female
# 2002    Female
# 2003      Male
# 2004      Male
# 2005      Male
# Name: Gender, Length: 2006, dtype: str

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Attendance'].dropna()
# Out:
# 0       68.0
# 1       61.0
# 2       95.0
# 3       60.0
# 4       73.0
#         ...
# 2001    78.0
# 2002    90.0
# 2003    93.0
# 2004    69.0
# 2005    72.0
# Name: Attendance, Length: 1994, dtype: float64

# %%
df.isnull().sum()
# Out:
# Student_ID     0
# Name           0
# Age           19
# Gender         9
# Department     9
# City           8
# Marks          7
# Attendance     6
# dtype: int64
